# %% [markdown]
# - LIBRARIES: libraries is a set of functions/methods, attributes , data types
# - EXAMPLES OF LIBRARIES:
# > PANDAS -
# > NUMPY  -
# > MATPLOTLIB-
# > SEABORN -
# > SKLEARN-
# > SKIPY-
# > TENSOR FLOW-
# > KERAS-
# > PICKLE-

# %%
# !pip install pandas  "#(prefered installer programmer)"
# Out:
# ERROR: Invalid requirement: '#(prefered installer programmer)'

# %%
import pandas

# %%
pandas.read_csv(filepath_or_buffer=r"C:\Users\PRIYANKA\Data_Science_14_april_jhon\data_Sets\drinks (1).csv")
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %% [markdown]
# ### Chapter : 01 -Getting and knowing your data

# %%
import pandas as pd

# %%
order_details=pd.read_csv(filepath_or_buffer=r"C:\Users\PRIYANKA\Data_Science_14_april_jhon\data_Sets\data.tsv (1).txt",sep="\t")
order_details
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# #### 1.1 perforn initial analysis

# %%
order_details.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
order_details.head(20)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# ...

# %%
order_details.tail()
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
order_details.shape
# Out:
# (4622, 5)

# %% [markdown]
# #### TERMINOLOGY ALERT
#
# * ROWS - OBSERVATIONS/RECORDS/DATA POINTS
# * COLUMNS - FEATURES / PARAMETERS.

# %%
order_details.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
order_details.describe(include='all')
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %%
order_details.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
order_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %% [markdown]
# #### 1.2 Which item has been ordered most? Give me the top 5

# %%
order_details.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
order_details.groupby(by='item_name')['quantity'].sum().sort_values(ascending=False).head()
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Steak Burrito          386
# Canned Soft Drink      351
# Name: quantity, dtype: int64

# %%
order_details.groupby(by='item_name')['quantity'].sum().sort_values(ascending=False).tail(10)
# Out:
# item_name
# Burrito                              6
# Veggie Salad                         6
# Carnitas Salad Bowl                  6
# Bowl                                 4
# Steak Salad                          4
# Salad                                2
# Crispy Tacos                         2
# Chips and Mild Fresh Tomato Salsa    1
# Carnitas Salad                       1
# Veggie Crispy Tacos                  1
# Name: quantity, dtype: int64

# %% [markdown]
# ### CHAPTER 02:FILTERING AND SORTING

# %%
euro_stats=pd.read_csv(r'C:\Users\PRIYANKA\Data_Science_14_april_jhon\data_Sets\Euro_2012_stats_TEAM (1).csv')

# %%
pd.set_option('max_columns',None)# NO RESTRICTION IN DISPLAYING THE COLUMNS

# %%
euro_stats
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro_stats.columns
# Out:
# Index(['Team', 'Goals', 'Shots on target', 'Shots off target',
#        'Shooting Accuracy', '% Goals-to-shots', 'Total shots (inc. Blocked)',
#        'Hit Woodwork', 'Penalty goals', 'Penalties not scored', 'Headed goals',
#        'Passes', 'Passes completed', 'Passing Accuracy', 'Touches', 'Crosses',
#        'Dribbles', 'Corners Taken', 'Tackles', 'Clearances', 'Interceptions',
#        'Clearances off line', 'Clean Sheets', 'Blocks', 'Goals conceded',
#        'Saves made', 'Saves-to-shots ratio', 'Fouls Won', 'Fouls Conceded',
#        'Offsides', 'Yellow Cards', 'Red Cards', 'Subs on', 'Subs off',
#        'Players Used'],
#       dtype='object')

# %%
#FILTERING 4 COLUMNS OUT OF 35 COLUMNS
filtered_data=euro_stats[['Team', 'Shooting Accuracy',  'Yellow Cards', 'Red Cards']]
filtered_data
# Out:
#                    Team Shooting Accuracy  Yellow Cards  Red Cards
# 0               Croatia             51.9%             9          0
# 1        Czech Republic             41.9%             7          0
# 2               Denmark             50.0%             4          0
# 3               England             50.0%             5          0
# 4                France             37.9%             6          0
# 5               Germany             47.8%             4          0
# 6                Greece             30.7%             9          1
# 7                 Italy             43.0%            16          0
# 8           Netherlands             25.0%             5          0
# 9                Poland             39.4%             7          1
# 10             Portugal             34.3%            12          0
# 11  Republic of Ireland             36.8%             6          1
# 12               Russia             22.5%             6          0
# ...

# %%
filtered_data.sort_values(by='Yellow Cards',ascending=True)
# Out:
#                    Team Shooting Accuracy  Yellow Cards  Red Cards
# 2               Denmark             50.0%             4          0
# 5               Germany             47.8%             4          0
# 3               England             50.0%             5          0
# 8           Netherlands             25.0%             5          0
# 15              Ukraine             21.2%             5          0
# 4                France             37.9%             6          0
# 11  Republic of Ireland             36.8%             6          1
# 12               Russia             22.5%             6          0
# 1        Czech Republic             41.9%             7          0
# 9                Poland             39.4%             7          1
# 14               Sweden             47.2%             7          0
# 0               Croatia             51.9%             9          0
# 6                Greece             30.7%             9          1
# ...

# %%
filtered_data[filtered_data['Team']=='Croatia']
# Out:
#       Team Shooting Accuracy  Yellow Cards  Red Cards
# 0  Croatia             51.9%             9          0

# %%
filtered_data[filtered_data['Red Cards']==1]
# Out:
#                    Team Shooting Accuracy  Yellow Cards  Red Cards
# 6                Greece             30.7%             9          1
# 9                Poland             39.4%             7          1
# 11  Republic of Ireland             36.8%             6          1

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
filtered_data.sort_values(by='Yellow Cards',ascending=False,inplace=True) # impacts the original data

# %%
filtered_data
# Out:
#                    Team Shooting Accuracy  Yellow Cards  Red Cards
# 7                 Italy             43.0%            16          0
# 10             Portugal             34.3%            12          0
# 13                Spain             55.9%            11          0
# 0               Croatia             51.9%             9          0
# 6                Greece             30.7%             9          1
# 1        Czech Republic             41.9%             7          0
# 9                Poland             39.4%             7          1
# 14               Sweden             47.2%             7          0
# 4                France             37.9%             6          0
# 11  Republic of Ireland             36.8%             6          1
# 12               Russia             22.5%             6          0
# 3               England             50.0%             5          0
# 8           Netherlands             25.0%             5          0
# ...

# %%
filtered_data[filtered_data['Yellow Cards']>9]
# Out:
#         Team Shooting Accuracy  Yellow Cards  Red Cards
# 7      Italy             43.0%            16          0
# 10  Portugal             34.3%            12          0
# 13     Spain             55.9%            11          0

# %%
filtered_data[(filtered_data['Yellow Cards']>9) | (filtered_data['Red Cards']==1)]
# Out:
#                    Team Shooting Accuracy  Yellow Cards  Red Cards
# 7                 Italy             43.0%            16          0
# 10             Portugal             34.3%            12          0
# 13                Spain             55.9%            11          0
# 6                Greece             30.7%             9          1
# 9                Poland             39.4%             7          1
# 11  Republic of Ireland             36.8%             6          1

# %%
filtered_data[(filtered_data['Yellow Cards']>9) & (filtered_data['Red Cards']==1)]
# Out:
# Empty DataFrame
# Columns: [Team, Shooting Accuracy, Yellow Cards, Red Cards]
# Index: []

# %% [markdown]
# ### CHAPTER 04 - DELETE

# %%
euro_2012=pd.read_csv(r"C:\Users\PRIYANKA\Data_Science_14_april_jhon\data_Sets\Euro_2012_stats_TEAM (1).csv")
euro_2012
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro_2012.set_index(keys='Team')
# Out:
#                      Goals  Shots on target  Shots off target  \
# Team
# Croatia                  4               13                12
# Czech Republic           4               13                18
# Denmark                  4               10                10
# England                  5               11                18
# France                   3               22                24
# Germany                 10               32                32
# Greece                   5                8                18
# Italy                    6               34                45
# Netherlands              2               12                36
# Poland                   2               15                23
# Portugal                 6               22                42
# Republic of Ireland      1                7                12
# Russia                   5                9                31
# Spain                   12               42                33
# ...

# %%
del euro_2012['Shooting Accuracy'] # delete one colum at once

# %%
euro_2012
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro_2012.drop(['Hit Woodwork','Penalty goals'],axis=1,inplace=True)

# %%
euro_2012
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro_2012.Team
# Out:
# 0                 Croatia
# 1          Czech Republic
# 2                 Denmark
# 3                 England
# 4                  France
# 5                 Germany
# 6                  Greece
# 7                   Italy
# 8             Netherlands
# 9                  Poland
# 10               Portugal
# 11    Republic of Ireland
# 12                 Russia
# 13                  Spain
# 14                 Sweden
# 15                Ukraine
# Name: Team, dtype: object

# %%
euro_2012['Team']
# Out:
# 0                 Croatia
# 1          Czech Republic
# 2                 Denmark
# 3                 England
# 4                  France
# 5                 Germany
# 6                  Greece
# 7                   Italy
# 8             Netherlands
# 9                  Poland
# 10               Portugal
# 11    Republic of Ireland
# 12                 Russia
# 13                  Spain
# 14                 Sweden
# 15                Ukraine
# Name: Team, dtype: object

# %% [markdown]
# ### CHAPTER 05 -  APPLY FUNCTION

# %%
student_details=pd.read_csv(r"C:\Users\PRIYANKA\Data_Science_14_april_jhon\data_Sets\student-mat.csv")
student_details
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
student_details['Medu']=student_details['Medu']+2

# %%
student_details['Mjob'].upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_40596/3604147271.py in <module>
# ----> 1 student_details['Mjob'].upper()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'upper'

# %% [markdown]
# ### CHAPTER-06  CREATING SERIES AND DATAFRAME
# pandas has 2 data structure
#
# 1.1D -SERIES
#
# 2.2D - DATAFRAME

# %%
vinay_scores=[10,20,30,40,50,60]
vinay_scores
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
type(vinay_scores)
# Out:
# list

# %%
data=pd.Series(data=[10, 20, 30, 40, 50, 60])
data
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# dtype: int64

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
learner_details=pd.DataFrame(data={'fname':['Vinay','Gaurav'],
                                  'age':[24,26]})
learner_details
# Out:
#     fname  age
# 0   Vinay   24
# 1  Gaurav   26

# %%
type(learner_details)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### CHAPTER 08 - GROUPING VS PIVOT TABLE VS CROSSTAB
# - grouping the data according to the categories and apply a function to the categories.
# - Pivot table in pandas is an excellent tool to summarize one or more numeric variable based on two other categorical variables
# - Cross tabulation is used to quantitatively analyze the relationship between multiple variables.

# %%
insurance_details=pd.read_csv(r"C:\Users\PRIYANKA\Data_Science_14_april_jhon\data_Sets\insurance.csv")
insurance_details
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ## CLUE TO USE GROUPBY FUNCTION
#
# DISCRETE VS CONTINUES DATA TYPES
#
# **DISCRETE** - COUNTABLE BUT NOT MEASURABLE(NO UNITS) AND CANNOT BE SEGREGATTED
#
#
# **CONTINUOUS** - MEASURABLE(UNITS), CAN BE SEGREGATTED
#
# groupby(discrete data)[cont data]

# %% [markdown]
# #### 8.1 ON AN AVERAGE WHICH REGION IS GETTING MORE INSURANCE CHARGES

# %%
insurance_details.groupby(by='region')['charges'].mean().sort_values(ascending=False)
# Out:
# region
# southeast    14735.411438
# northeast    13406.384516
# northwest    12417.575374
# southwest    12346.937377
# Name: charges, dtype: float64

# %%
insurance_details.groupby(by='region')['charges'].mean().sort_values(ascending=True)
# Out:
# region
# southwest    12346.937377
# northwest    12417.575374
# northeast    13406.384516
# southeast    14735.411438
# Name: charges, dtype: float64

# %% [markdown]
# #### 8.2  ON AN AVERAGE WHICH REGION IS GETTING MAX INSURANCE CHARGES

# %%
insurance_details.groupby(by='region')['charges'].max().sort_values(ascending=False)
# Out:
# region
# southeast    63770.42801
# northwest    60021.39897
# northeast    58571.07448
# southwest    52590.82939
# Name: charges, dtype: float64

# %%
####  ON AN AVERAGE WHICH GENDER IS GETTING MAX INSURANCE CHARGES
insurance_details.groupby(by='sex')['charges'].mean().sort_values(ascending=False).round()
# Out:
# sex
# male      13957.0
# female    12570.0
# Name: charges, dtype: float64

# %% [markdown]
# #### 8.3 BASED ON REGION AND SMOKERS WHAT IS THE AVERAGE INSURANCE CHARGES?

# %%
insurance_details.groupby(by=['smoker','region'])['charges'].mean().sort_values(ascending=False).round()
# Out:
# smoker  region
# yes     southeast    34845.0
#         southwest    32269.0
#         northwest    30192.0
#         northeast    29674.0
# no      northeast     9166.0
#         northwest     8556.0
#         southeast     8032.0
#         southwest     8019.0
# Name: charges, dtype: float64

# %%
insurance_details.groupby(by=['smoker','region','children'])['charges'].mean().sort_values(ascending=False).round()
# Out:
# smoker  region     children
# yes     southeast  2           37619.0
#         southwest  2           37569.0
#         northwest  3           36160.0
#         southeast  0           35515.0
#         southwest  1           34550.0
#         northeast  3           34004.0
#         southeast  3           32551.0
#                    1           32503.0
#         northeast  1           32340.0
#         northwest  2           31032.0
#         southwest  0           30852.0
#                    4           29062.0
#         northwest  0           28333.0
#         northeast  0           28167.0
#         northwest  1           26470.0
#         northeast  2           22696.0
#         southwest  3           21617.0
#         northwest  4           21472.0
#         southwest  5           19023.0
# no      northeast  4           14485.0
#         southeast  4           14451.0
#                    3           11987.0
#         northeast  2           11669.0
# ...

# %%
pd.pivot_table(data = insurance_details,values = 'charges',index='region',columns=['smoker','children'],aggfunc='mean').round()
# Out:
# smoker         no                                                  yes  \
# children        0       1        2        3        4        5        0
# region
# northeast  8072.0  9898.0  11669.0   7653.0  14485.0   6979.0  28167.0
# northwest  7545.0  7982.0   9951.0  10548.0   9322.0   8966.0  28333.0
# southeast  7060.0  8016.0   7520.0  11987.0  14451.0  10115.0  35515.0
# southwest  7754.0  7647.0   8947.0   8650.0   9282.0   6933.0  30852.0
#
# smoker
# children         1        2        3        4        5
# region
# northeast  32340.0  22696.0  34004.0      NaN      NaN
# northwest  26470.0  31032.0  36160.0  21472.0      NaN
# southeast  32503.0  37619.0  32551.0      NaN      NaN
# southwest  34550.0  37569.0  21617.0  29062.0  19023.0

# %%
pd.pivot_table(data = insurance_details,values = 'charges',index='region',columns=['smoker'],aggfunc='mean').round().sort_values(by='yes',ascending=False)
# Out:
# smoker         no      yes
# region
# southeast  8032.0  34845.0
# southwest  8019.0  32269.0
# northwest  8556.0  30192.0
# northeast  9166.0  29674.0

# %% [markdown]
# ### 8.4 HOW MANY SMOKERS ARE MALE AND FEMALE

# %%
insurance_details
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
#to compare discrete columns  we use crosstab function

pd.crosstab(index=insurance_details['sex'],columns=insurance_details['smoker'],margins=True)
# Out:
# smoker    no  yes   All
# sex
# female   547  115   662
# male     517  159   676
# All     1064  274  1338

# %%
insurance_details.shape
# Out:
# (1338, 7)

# %% [markdown]
# #### QUICK EXERCISE

# %% [markdown]
# ### Use u.user file and comeup with atleast 1 insight

# %%
user_details=pd.read_csv(r"C:\Users\PRIYANKA\Data_Science_14_april_jhon\data_Sets\u (1).user",sep='|')
user_details
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# ### Q: BASED ON GENDER WHAT IS THE AVERAGE AGE OF THE PEOPLE

# %%
user_details.groupby(by='gender')['age'].mean().sort_values(ascending=False).round()
# Out:
# gender
# M    34.0
# F    34.0
# Name: age, dtype: float64

# %% [markdown]
# ### Q: BASED ON OCCUPATION WHAT IS THE AVERAGE AGE OF PEOPLE

# %%
user_details.groupby(by='occupation')['age'].mean().sort_values(ascending=False).round()
# Out:
# occupation
# retired          63.0
# doctor           44.0
# educator         42.0
# healthcare       42.0
# librarian        40.0
# administrator    39.0
# executive        39.0
# marketing        38.0
# lawyer           37.0
# engineer         36.0
# writer           36.0
# salesman         36.0
# scientist        36.0
# other            35.0
# technician       33.0
# programmer       33.0
# homemaker        33.0
# artist           31.0
# entertainment    29.0
# none             27.0
# student          22.0
# Name: age, dtype: float64

# %% [markdown]
# ### Q: BASED ON GENDER  WHAT IS THE MAX NUMBER OF OCCUPATION

# %%
pd.crosstab(index=user_details['gender'],columns=user_details['occupation'],margins=True)
# Out:
# occupation  administrator  artist  doctor  educator  engineer  entertainment  \
# gender
# F                      36      13       0        26         2              2
# M                      43      15       7        69        65             16
# All                    79      28       7        95        67             18
#
# occupation  executive  healthcare  homemaker  lawyer  librarian  marketing  \
# gender
# F                   3          11          6       2         29         10
# M                  29           5          1      10         22         16
# All                32          16          7      12         51         26
#
# occupation  none  other  programmer  retired  salesman  scientist  student  \
# gender
# F              4     36           6        1         3          3       60
# M              5     69          60       13         9         28      136
# All            9    105          66       14        12         31      196
#
# ...

# %% [markdown]
# ### Q:  BASED ON OCCUPATION WHAT IS THE AVERAGE AGE ?

# %%
user_details.groupby(by='occupation')['age'].mean().sort_values(ascending=False).round()
# Out:
# occupation
# retired          63.0
# doctor           44.0
# educator         42.0
# healthcare       42.0
# librarian        40.0
# administrator    39.0
# executive        39.0
# marketing        38.0
# lawyer           37.0
# engineer         36.0
# writer           36.0
# salesman         36.0
# scientist        36.0
# other            35.0
# technician       33.0
# programmer       33.0
# homemaker        33.0
# artist           31.0
# entertainment    29.0
# none             27.0
# student          22.0
# Name: age, dtype: float64

# %% [markdown]
# ### Q: HOW MANY PEOPLE ARE WORKING IN EACH OCCUPATION

# %%
user_details['occupation'].value_counts()
# Out:
# student          196
# other            105
# educator          95
# administrator     79
# engineer          67
# programmer        66
# librarian         51
# writer            45
# executive         32
# scientist         31
# artist            28
# technician        27
# marketing         26
# entertainment     18
# healthcare        16
# retired           14
# lawyer            12
# salesman          12
# none               9
# homemaker          7
# doctor             7
# Name: occupation, dtype: int64

# %% [markdown]
# #### DAILY TASK 07: EXPLORE PANDAS AGGREGATE FUNCTIONS

# %%
user_details.mean()
# Out:
# user_id    472.000000
# age         34.051962
# dtype: float64

# %%
user_details.median()
# Out:
# user_id    472.0
# age         31.0
# dtype: float64
